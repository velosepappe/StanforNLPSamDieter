# %%
import requests
from scrapy.http import TextResponse

url = "https://www.libelle-lekker.be/bekijk-recept/80272/tulbandamandelcake"
user_agent = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/58: .0.3029.110 Chrome/58.0.3029.110 Safari/537.36'}

r = requests.get(url, headers=user_agent)
response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
# Inhoud ingredienten json
c = response.xpath('//div/@data-ingredient-groups').extract()
print("#elements".format(len(c)))
print(c)
# Out:
# #elements
# ['[{"title":null,"id":1227301,"description":null,"ingredients":[{"itemType":null,"id":1354,"sortOrder":1,"quantity":"4.00","info":null,"plural":1,"important":null,"ingredient":{"id":1354,"langCode":"NL","countryCode":"BE","nameSelect":"rozijn, witte","nameDisplay":"witte rozijn","nameDisplayPlural":"witte rozijnen","description":"","isBasic":false,"product":{"description":"<p>\\n Wereldwijd bestaan er talloze druivenvari&euml;teiten waarvan de meeste bestemd zijn voor de wijnbouw. De populairste wijndruiven zijn de &#39;Cabernet Sauvignon&#39;, de &#39;Pinot Noir&#39;, de &#39;Syrah&#39; en de &#39;Merlot&#39; voor rode wijn, en de &#39;Riesling&#39;, de &#39;Chardonnay&#39;, de &#39;S&eacute;millon&#39;, de &#39;Sauvignon blanc&#39; en de &#39;Chenin blanc&#39; voor witte wijn.<\\/p>\\n<p>\\n Daarnaast zijn er druiven die speciaal voor consumptie worden geteeld. De bekendste Belgische druivensoorten zijn de &#39;Baidor&#39;, &#39;Canon Hall&#39; en &#39;Muscat&#39; voor de witte druiven en de &#39;Leopold III&#39;, &#39;Colman&#39;, &lsquo;Ribier&#39; en &#39;Royal&#39; voor de blauwe druiven.<\\/p>\\n<p>\\n Er bestaan ook pitloze druiven. De bekendste soorten zijn de &lsquo;Thompson&#39;, de &#39;Seedless&#39; en de &#39;Sultana&#39;.<\\/p>\\n<p>\\n &nbsp;<\\/p>\\n<p>\\n <b>Aankopen<\\/b><\\/p>\\n<p>\\n De beste periode om druiven te kopen, is van eind augustus tot eind oktober.<\\/p>\\n<p>\\n Druiven moeten bij aankoop volledig ongeschonden zijn. De aanwezigheid van een donslaagje, dat typisch is voor de Belgische druiven, wijst erop dat de druiven niet bespoten zijn. Deze druiven hoef je niet te wassen.<\\/p>\\n<p>\\n Druiven zijn erg kwetsbaar. Neem ze dus steeds bij de steel en raak de vruchten zelf zo weinig mogelijk aan.<\\/p>\\n<p>\\n &nbsp;<\\/p>\\n<p>\\n <b>Bewaren<\\/b><\\/p>\\n<p>\\n Je bewaart druiven het beste in de koelkast. Gewikkeld in geperforeerd papier zijn ze tot 5 dagen houdbaar. Druiven kunnen ook perfect in de diepvries worden bewaard om ze later in warme bereidingen te gebruiken.<\\/p>\\n<p>\\n Haal druiven een uurtje voor gebruik uit de koelkast om ze op kamertemperatuur te laten komen. Onbespoten druiven kan je zo eten. Druiven die wel bespoten zijn, moet je uiteraard zorgvuldig wassen met stromend water. Was enkel de druiven die je onmiddellijk verbruikt.<\\/p>\\n<p>\\n Als je druiven wilt schillen, dompel je ze enkele seconden onder in kokend water en laat je ze vervolgens schrikken onder koud water. De schil zal daarna makkelijk verwijderbaar zijn met een scherp mes. Om druiven te ontpitten, gebruik je het beste een grote naald.<\\/p>\\n<p>\\n Verse druiven zijn heerlijk in combinatie met ontbijtgranen, bij het aperitief, in een fruitslaatje of bij een kaasschotel. Maar ook in salades en sausen komen druiven goed tot hun recht.<\\/p>\\n<p>\\n &nbsp;<\\/p>\\n<p>\\n <b>Gezondheid<\\/b><\\/p>\\n<p>\\n Druiven zijn rijk aan druivensuiker en leveren bijgevolg flink wat energie. Druiven bevatten ook veel organische zuren en vitamines uit de B-groep. Door de aanwezigheid van polyfenolen zijn druiven ook goed voor hart- en bloedvaten. Als je gevoelige darmen hebt, kan je best de schil en de pitten verwijderen.<\\/p>\\n<table border=\\"0\\" cellpadding=\\"0\\" cellspacing=\\"0\\" width=\\"351\\">\\n <tbody>\\n  <tr>\\n   <td align=\\"center\\" bgcolor=\\"#cccccc\\" valign=\\"middle\\">\\n    <table border=\\"0\\" cellpadding=\\"0\\" cellspacing=\\"1\\" class=\\"designed\\" width=\\"350\\">\\n     <tbody>\\n      <tr bgcolor=\\"#ffffff\\">\\n       <td colspan=\\"2\\" height=\\"30\\">\\n        <p>\\n         <font color=\\"#666633\\">&nbsp;Voedingswaarde per 100 g<\\/font><\\/p>\\n       <\\/td>\\n      <\\/tr>\\n      <tr>\\n       <td bgcolor=\\"#ffffff\\" valign=\\"top\\" width=\\"190\\">\\n        <p>\\n         &nbsp;energie<\\/p>\\n       <\\/td>\\n       <td bgcolor=\\"#ffffff\\" valign=\\"top\\" width=\\"236\\">\\n        <p>\\n         &nbsp;297 kJ \\/ 71 kcal<\\/p>\\n       <\\/td>\\n      <\\/t ...

# %%
# Text inhoud van alle 'stappen'
response.xpath('//p[@class="step-number"]/following-sibling::p/text()').extract()
# Out:
# ['Verwarm de oven voor op 190°C. Splits de eieren en mix het eiwit met 4 el suiker stijf. Mix in een andere kom de eidooiers met de sinaasappelrasp, kaneel en de resterende suiker romig. Spatel er het amandelmeel en een snuifje zout onder. Meng in delen het stijfgeklopte eiwit door het beslag. Meng er ook de rozijnen onder.',
#  'Vet een tulbandvorm in met boter en giet er het beslag in. Zet de taart 40 minuten in de oven. Laat de cake in de vorm afkoelen.',
#  'Giet net voor het serveren de honing over de taart en strooi er het fijngehakte amandelschaafsel over.',
#  'Verwarm de oven voor op 190°C. Splits de eieren en mix het eiwit met 4 el suiker stijf. Mix in een andere kom de eidooiers met de sinaasappelrasp, kaneel en de resterende suiker romig. Spatel er het amandelmeel en een snuifje zout onder. Meng in delen het stijfgeklopte eiwit door het beslag. Meng er ook de rozijnen onder.',
#  'Vet een tulbandvorm in met boter en giet er het beslag in. Zet de taart 40 minuten in de oven. Laat de cake in de vorm afkoelen.',
#  'Giet net voor het serveren de honing over de taart en strooi er het fijngehakte amandelschaafsel over.']
