# %%
f = open('E:/Tesseract/test/out.txt')

# %%
raw = f.read()

# %%
raw
# Out:
# ' \n\nHUUROVEREENKOMST VOOR EEN HOOFDVERBLIJFPLAATS\n\n \n\nVOORWOORD\n\n \n\nUw contract bestaat uit twee delen\n4. _De algemene voorwaarden\n\nbeschrijven de werking van het contract en verduidelijken de wederzijdse verbintenissen.\n2. De bijzondere voorwaarden\n\nbeschrijven de persoonlijke gegevens en variabelen van het contract. Zij vermelden oa. de gegevens van\npartijen, het onroerend goed, de huurtermijn, de huurprijs, de lasten, de waarborg, enz.\n\nHoe uw contract raadplegen ?\n\n(op de volgende bladzijde vindt u een inhoudstael, die u een overzicht geeft van de verschilende artikels van\nhet huurcontract, waar u deze terugvindt\n\nZo kunt u elk bepaald punt dat u wenst te raadplegen snel terugvinden,\n\n \n\n \n\nEe INHOUDSTAFEL Eel\nALGEMENE VOORWAARDEN\nART. Wie zijn de partijen ?\nART.2 Welk onroerend goed ?\nART.3 Wat is het doel van het contract?\nART.4 Hoelang loopt deze overeenkomst ?\n\nWie kan opzeggen en wanneer 7\n$ 1. contract met een duur van drie jaar en minder\n$ 2. contract met een duur van negen jaar\n\nART.5 De betaling van de huurprijs.\n1. Wat moet betaald worden 7\n2. Wanneer moet betaald worden ?\n3. Indexering van de huurprijs.\n4. Herziening van de huurprijs\n\nART.6 De huurwaarborg\n\nART.7 De staat van het gehuurde goed\nDe plaatsbeschrijving\n\nART.8 Onderhoud en herstelingen\n1. Welke zijn ten laste van de verhuurder 2\n2 Welke zijn ten laste van de huurder ?\n\nART. 9 Lasten en provisies\n\nART. 10 Verzekering\n\nART. 11 Onderverhuring en huuroverdracht\n\nART. 12 Bestemming van het goed\n\nART. 13 Verfraaiings-, verbeterings- en veranderingswerken\n\nperst paodle 1\n#\n\x0c'

# %%
import nltk
import re
from nltk.corpus import conll2002
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('treebank')
nltk.download('conll2002')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     C:\Users\ingel\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2002 is already up-to-date!
# True

# %%
vnv = """
 (
 is/V|    # 3rd sing present and
 was/V|   # past forms of the verb zijn ('be')
 werd/V|  # and also present
 wordt/V  # past of worden ('become)
 )
 .*       # followed by anything
 van/Prep # followed by van ('of')
 """
VAN = re.compile(vnv, re.VERBOSE)

# %%
f = open('E:/Tesseract/test/out.txt')
for line in f:
    tokens = nltk.word_tokenize(line.strip())
    tagged = nltk.pos_tag(tokens)
    entities = nltk.chunk.ne_chunk(tagged)
    print(entities)
    for r in nltk.sem.extract_rels('PER', 'ORG', entities, corpus='conll2002', pattern=VAN):
        print(nltk.sem.clause(r, relsym="VAN"))
# Out:
# (S )
# (S )
# (S
#   (ORGANIZATION HUUROVEREENKOMST/NNP)
#   (ORGANIZATION VOOR/NNP)
#   EEN/NNP
#   HOOFDVERBLIJFPLAATS/NNP)
# (S )
# (S )
# (S )
# (S (ORGANIZATION VOORWOORD/NN))
# (S )
# (S )
# (S )
# (S (GPE Uw/NNP) contract/NN bestaat/NN uit/NN twee/NN delen/NN)
# (S 4/CD ./. _De/JJ algemene/NN voorwaarden/NN)
# (S )
# (S
#   beschrijven/RB
#   de/IN
#   werking/VBG
#   van/NN
#   het/NN
#   contract/NN
#   en/IN
#   verduidelijken/FW
#   de/FW
#   wederzijdse/FW
#   verbintenissen/FW
#   ./.)
# (S 2/CD ./. (PERSON De/NNP) bijzondere/FW voorwaarden/NN)
# (S )
# (S
#   beschrijven/RB
#   de/FW
#   persoonlijke/FW
#   gegevens/NNS
#   en/FW
#   variabelen/FW
#   van/FW
#   het/NN
#   contract/NN
#   ./.
#   Zij/NNP
#   vermelden/JJ
#   oa/NN
#   ./.
#   de/IN
#   gegevens/NNS
#   van/NNS)
# (S
#   partijen/NN
#   ,/,
#   het/JJ
#   onroerend/VBP
#   goed/NN
#   ,/,
#   de/FW
#   huurtermijn/FW
#   ,/,
#   de/FW
#   huurprijs/FW
#   ,/,
#   de/FW
#   lasten/FW
#   ,/,
#   de/FW
#   waarborg/FW
#   ,/,
#   enz/FW
#   ./.)
# (S )
# (S (GPE Hoe/NNP) uw/JJ contract/NN raadplegen/NN ?/.)
# (S )
# (S
#   (/(
#   op/FW
#   de/FW
#   volgende/FW
#   bladzijde/NN
#   vindt/NN
#   u/JJ
#   een/JJ
#   inhoudstael/NN
#   ,/,
#   die/VBP
#   u/JJ
#   een/JJ
#   overzicht/NN
#   geeft/VBD
#   van/NN
#   de/IN
#   verschilende/FW
#   artikels/NNS
#   van/VBP)
# (S het/NN huurcontract/NN ,/, waar/WP u/JJ deze/NN terugvindt/NN)
# (S )
# (S
#   (GPE Zo/NNP)
#   kunt/NN
#   u/JJ
#   elk/NN
#   bepaald/NN
#   punt/NN
#   dat/NN
#   u/NN
#   wenst/NN
#   te/NN
#   raadplegen/NN
#   snel/NN
#   terugvinden/NN
#   ,/,)
# (S )
# (S )
# (S )
# (S )
# (S )
# (S Ee/NNP INHOUDSTAFEL/NNP Eel/NNP)
# (S (ORGANIZATION ALGEMENE/NNP) (ORGANIZATION VOORWAARDEN/NNP))
# (S ART/NN ./. (PERSON Wie/NNP) zijn/NNP de/IN partijen/FW ?/.)
# (S ART.2/NNP Welk/NNP onroerend/VBP goed/NN ?/.)
# (S
#   ART.3/NNP
#   Wat/NNP
#   is/VBZ
#   het/JJ
#   doel/NN
#   van/NN
#   het/NN
#   contract/NN
#   ?/.)
# (S
#   ART.4/NNP
#   (PERSON Hoelang/NNP)
#   loopt/NN
#   deze/NN
#   overeenkomst/NN
#   ?/.)
# (S )
# (S (PERSON Wie/NNP) kan/VBD opzeggen/RP en/JJ wanneer/NN 7/CD)
# (S
#   $/$
#   1./CD
#   contract/NN
#   met/VBD
#   een/JJ
#   duur/NN
#   van/NN
#   drie/NN
#   jaar/NN
#   en/IN
#   minder/NN)
# (S
#   $/$
#   2./CD
#   contract/NN
#   met/VBD
#   een/JJ
#   duur/NN
#   van/NN
#   negen/NN
#   jaar/NN)
# (S )
# (S ART.5/NNP De/NNP betaling/VBG van/NN de/IN huurprijs/NN ./.)
# (S 1/CD ./. (PERSON Wat/NNP) moet/NN betaald/NN worden/VBZ 7/CD)
# (S 2/CD ./. (PERSON Wanneer/NNP) moet/NN betaald/NN worden/NN ?/.)
# (S 3/LS ./. Indexering/VBG van/NN de/IN huurprijs/NN ./.)
# (S 4/CD ./. Herziening/VBG van/NN de/FW huurprijs/NN)
# (S )
# (S ART.6/NNP De/NNP huurwaarborg/NN)
# (S )
# (S ART.7/NNP De/NNP staat/FW van/NN het/NN gehuurde/NN goed/NN)
# (S (GPE De/NNP) plaatsbeschrijving/NN)
# (S )
# (S ART.8/NNP Onderhoud/NNP en/FW herstelingen/NN)
# (S
#   1/CD
#   ./.
#   (PERSON Welke/NNP)
#   zijn/NNP
#   ten/VBD
#   laste/JJ
#   van/NN
#   de/IN
#   verhuurder/FW
#   2/CD)
# (S
#   2/CD
#   Welke/NNP
#   zijn/NNP
#   ten/VBD
#   laste/JJ
#   van/NN
#   de/IN
#   huurder/NN
#   ?/.)
# (S )
# (S ART/NNP ./. 9/CD Lasten/NNP en/NN provisies/NNS)
# (S )
# (S ART/NNP ./. 10/CD Verzekering/VBG)
# (S )
# (S ART/NNP ./. 11/CD Onderverhuring/VBG en/NN huuroverdracht/NN)
# (S )
# (S ART/NNP ./. 12/CD Bestemming/NNP van/NN het/NN goed/NN)
# (S )
# (S
#   ART/NNP
#   ./.
#   13/CD
#   Verfraaiings-/JJ
#   ,/,
#   verbeterings-/JJ
#   en/NN
#   veranderingswerken/NN)
# (S )
# (S perst/RB paodle/VBZ 1/CD)
# (S #/#)
# (S )
